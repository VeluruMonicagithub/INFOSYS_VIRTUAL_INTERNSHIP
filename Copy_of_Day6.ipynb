# %% [markdown]
# <a href="https://colab.research.google.com/github/VeluruMonicagithub/INFOSYS_VIRTUAL_INTERNSHIP/blob/main/Copy_of_Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sounddevice vosk faster-whisper soundfile gtts
# !apt-get install -y portaudio19-dev

# %%
from gtts import gTTS
from IPython.display import Audio

tts = gTTS("Hello, this is a test audio for speech to text models.", lang="en")
tts.save("test_audio.mp3")

Audio("test_audio.mp3")

# %%
# !ffmpeg -i test_audio.mp3 -ar 16000 -ac 1 test.wav -y

# %%
# !wget -q https://alphacephei.com/vosk/models/vosk-model-small-en-us-0.15.zip
# !unzip -q vosk-model-small-en-us-0.15.zip

from vosk import Model, KaldiRecognizer
import wave, json

wf = wave.open("test.wav", "rb")
rec = KaldiRecognizer(Model("vosk-model-small-en-us-0.15"), 16000)

result = ""
while True:
    data = wf.readframes(4000)
    if not data:
        break
    if rec.AcceptWaveform(data):
        result += json.loads(rec.Result())["text"] + " "

result += json.loads(rec.FinalResult())["text"]
print("VOSK:", result)

# %%
# !pip install -q faster-whisper

from faster_whisper import WhisperModel
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
model = WhisperModel("small", device=device)

segments, info = model.transcribe("test.wav")
text = " ".join([s.text for s in segments])

print("WHISPER:", text)
