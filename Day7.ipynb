# %% [markdown]
# <a href="https://colab.research.google.com/github/VeluruMonicagithub/INFOSYS_VIRTUAL_INTERNSHIP/blob/main/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('sample.txt','w') as f:
  f.write("This text is going to convert into audio")

# %%
# !pip install gtts
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
# ...

# %%
from gtts import gTTS
from IPython.display import display,Audio
text = open("sample.txt").read()
tts = gTTS(text=text,lang = 'en')
tts.save("sample_audio.mp3")

display(Audio('sample_audio.mp3',autoplay=False))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import subprocess
subprocess.run(["ffmpeg", "-y", "-i", "sample_audio.mp3", "-ar", "16000", "-ac", "1", "audio.wav"],
               stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
print("Converted to audio.wav (16k mono)")
# Out:
# Converted to audio.wav (16k mono)

# %%
from gtts import gTTS
from IPython.display import display, Audio

# Note: The 'TTS' library is not compatible with the current Python version in this environment.
# Using gTTS as an alternative. gTTS does not support specific male/female voice selection directly.

text = "Hello this is an example of an audio generated using gTTS."
tts_gtts = gTTS(text=text, lang='en')
tts_gtts.save('generated_audio.wav') # Saving with a new name to avoid conflicts

display(Audio('generated_audio.wav', autoplay=False))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !mkdir -p ami_sample
# !wget -q https://groups.inf.ed.ac.uk/ami/AMICorpusSamples/ES2002a.Mix-Headset.wav -O ami_sample/ES2002a.wav

print("Downloaded AMI sample file:")
# !ls -lh ami_sample
# Out:
# Downloaded AMI sample file:
# total 0
# -rw-r--r-- 1 root root 0 Dec  2 12:30 ES2002a.wav

# %%
from IPython.display import Audio

Audio("ami_sample/ES2002a.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64," type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
